# %%
import neuroseries as nts

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import scipy.signal
import scipy.stats

import bk.load
import bk.plot
import bk.compute
import bk.signal

# %%
bk.load.current_session_linux()
neurons, metadata = bk.load.spikes()

states = bk.load.states()

df = {}
for state_name,state in states.items():
    fr = []
    for n in neurons:
        fr.append(len(n.restrict(state))/state.tot_length('s'))
    df.update({state_name:fr})
pd.DataFrame(df)
# Out:
# Rat : 8 on day : 6
# Working with session Rat08-20130713 @ /mnt/electrophy/Gabrielle/GG-Dataset-Light/Rat08/Rat08-20130713
# Data already saved in Numpy format, loading them from here:
# Rat08-20130713-neurons.npy
# Rat08-20130713-metadata.npy
#           Rem       sws      wake    drowsy  wake_homecage
# 0    0.730072  0.607425  0.742071  0.933575       0.778687
# 1    0.799241  1.078966  1.239854  2.373188       1.793202
# 2    0.661324  0.881243  0.611231  0.603865       0.623107
# 3    1.222691  1.366321  0.294987  0.539251       0.371740
# 4    2.689582  2.950672  2.927248  2.612319       2.300460
# ..        ...       ...       ...       ...            ...
# 247  0.800506  0.566301  0.277254  0.477657       0.258448
# 248  0.062843  0.133627  0.151529  0.089372       0.066284
# 249  0.092366  0.103374  0.129590  0.097826       0.066087
# 250  0.105863  0.080710  0.069455  0.069444       0.086346
# 251  0.478279  0.285919  0.240423  0.364734       0.298375
#
# [252 rows x 5 columns]
