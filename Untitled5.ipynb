# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.ndimage

# %%
import os

# %%
os.chdir('Y:/Facundo/Rat29/Rat29-070521/')

# %%
data = pd.read_hdf('Basler_acA1300-200uc__23135826__20210507_103034194DLC_resnet50_LinearTrackMay25shuffle1_1030000.h5')

# %%
data = data['DLC_resnet50_LinearTrackMay25shuffle1_1030000']

# %%
x = data['m_body']['x'][data['snout']['likelihood']>0.95]
y = data['m_body']['y'][data['snout']['likelihood']>0.95]

# %%
plt.imshow(scipy.ndimage.fourier_gaussian(a[0],1.1))
plt.clim([0, 1])

# %%
a = plt.hist2d(x,y,[100,25])
ax = plt.gca()
ax.invert_yaxis()
plt.clim([0, 200])

# %%
plt.plot(x,y)

# %%
for d in data: print()
